# %% [markdown]
# <a href="https://colab.research.google.com/github/gobbcuh/typescript/blob/main/typescript_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-84ea28cc-83b4-43c8-b98d-d911e547387e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84ea28cc-83b4-43c8-b98d-d911e547387e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### **Typescript**
# - enhanced version of Javascript
# - TS files are converted into JS files
# - objects can have types (has type-checking)
#
# npm init -y
# - to know the project is a node.js
#
# npm add typescript
# - to add typescript
#
# Initially, TS files cannot run in a browser. It needs to be compiled first, converting them into JS file.
#
# npm run build
# - to compile the TS file and build into JS file
#
# Typescript - for development
# Javascript - for production
#
#
# ### **2 Ways of Creating Types:**
# 1. Interface

# %%
Image('Screenshot 2025-06-28 091246.png')

# %%
Image('Screenshot 2025-06-28 092557.png')

# %% [markdown]
# 2. Type

# %%
Image('Screenshot 2025-06-28 093618.png')

# %% [markdown]
# Function returning a data type

# %%
Image('Screenshot 2025-06-28 094531.png')

# %% [markdown]
# Function with parameters

# %%
Image('Screenshot 2025-06-28 095542.png')

# %% [markdown]
# Function with an optional parameter

# %%
Image('Screenshot 2025-06-28 100041.png')

# %% [markdown]
# **generic vs. any**
#
# - generic - still shows the type it may return
#
# - any - unknown type at all like JS
